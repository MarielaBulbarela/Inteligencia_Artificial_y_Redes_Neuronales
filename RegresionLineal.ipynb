# %% [markdown]
# <a href="https://colab.research.google.com/github/MarielaBulbarela/Inteligencia_Artificial_y_Redes_Neuronales/blob/main/RegresionLineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# MARIELA BULBARELA VAZQUEZ 2109277 CLASE:N1

# %% [markdown]
# **ACTIVIDAD 3: Solución de problemas**

# %%
# Cargar librerías
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Cargar datos
np.random.seed(0)
horas_estudio = np.random.rand(100, 1) * 10
calificaciones = 2 * horas_estudio + np.random.randn(100,1) * 2

# %%
# Preprocesamiento de datos
train_data, test_data, train_labels, test_labels = train_test_split(horas_estudio, calificaciones, test_size=0.2, random_state=42)

# %%
# Selección y entrenamiento del modelo
modelo = LinearRegression()
modelo.fit(train_data, train_labels)
# Out:
# LinearRegression()

# %%
# Prueba de modelo
predicciones = modelo.predict(test_data)
mse = mean_squared_error(test_labels, predictions)
print("Error:", mse)
# Out:
# Error: 3.671012987885716

# %%
# Visualización de resultados
plt.scatter(train_data, train_labels, color='blue', label='Datos de entrenamiento')
plt.scatter(test_data, test_labels, color='yellow', label='Datos de prueba')
plt.plot(test_data, predictions, color='black', label='Modelo de regresión lineal')
plt.xlabel('Horas de estudio')
plt.ylabel('Calificación')
plt.title('Modelo de regresión lineal para predicción de calificaciones')
plt.legend()
plt.show()
